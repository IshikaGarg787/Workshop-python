# %%
# XAMPP control panel v3.3.0
# angry ip scanner - to check how many devices are connected to your device.

# %%
# port scanner-----
import socket
target = input("Enter target IP or hostname:")
start_port = int(input("Enter start port: "))
end_port = int(input("Enter end port: "))

print(f"\nScanning {target} fro port {start_port} to {end_port}...\n")

for port in range(start_port, end_port + 1):
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)    # most important line
    s.settimeout(0.5)  # set timeout to speed up scan
    result = s.connect_ex((target, port))
    if result == 0:
        print(f"[OPEN] Port {port}")
    s.close() 

print("\nScan complete.")
# Out:
# Scanning 172.16.148.41 fro port 130 to 140...
#
# [OPEN] Port 135
# [OPEN] Port 139
#
# Scan complete.

# %%
# input start = 130
# input stop = 140
# IPv4 = 172.16.148.41 , 192.168.106.77

# %%
# exploit = tool used to break vulnerability

# %%
# port scanner with GUI------

import tkinter as tk
import socket

root=tk.Tk()
root.geometry('300x300')
root.title('port scanner with gui')

IPadd = tk.StringVar()
start_port = tk.StringVar()
end_port = tk.StringVar()

def scan():
    ip = IPadd.get()
    start = int(start_port.get())
    end = int(end_port.get())

    print(f"\nScanning {ip} fro port {start} to {end}...\n")

    for port in range(start, end + 1):
        s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)    # most important line
        s.settimeout(0.5)  # set timeout to speed up scan
        result = s.connect_ex((ip, port))
        if result == 0:
            print(f"[OPEN] Port {port}")
        s.close() 
    print("\nScan complete.")    

tk.Label(root, text='Enter IP Address: ').pack()
IPentry=tk.Entry(root, textvariable=IPadd).pack(pady=10)

tk.Label(root, text='enter starting port: ').pack()
start_entry=tk.Entry(root, textvariable=start_port).pack(pady=10)

tk.Label(root, text='enter ending port: ').pack()
end_entry=tk.Entry(root, textvariable=end_port).pack(pady=10)

btn=tk.Button(root,text='scan',command=scan).pack()

root.mainloop()

# %%
#gui and socket_prog together

import tkinter as tk
import socket

root=tk.Tk()
root.geometry('600x600')
root.title('port scanner with gui')

IPadd = tk.StringVar()
start_port = tk.StringVar()
end_port = tk.StringVar()

output_text = tk.Text(root, height=15, width=50)
output_text.pack(pady=10)

def scan():
    ip = IPadd.get()
    start = int(start_port.get())
    end = int(end_port.get())

    output_text.insert(tk.END,f"Scanning {ip} fro port {start} to {end}...\n")

    for port in range(start, end + 1):
        s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)    # most important line
        s.settimeout(0.5)  # set timeout to speed up scan
        result = s.connect_ex((ip, port))
        if result == 0:
            output_text.insert(tk.END,f"[OPEN] Port {port}\n")
        s.close() 
    output_text.insert(tk.END,f"Scan complete.\n")    

tk.Label(root, text='Enter IP Address: ').pack()
IPentry=tk.Entry(root, textvariable=IPadd).pack(pady=10)

tk.Label(root, text='enter starting port: ').pack()
start_entry=tk.Entry(root, textvariable=start_port).pack(pady=10)

tk.Label(root, text='enter ending port: ').pack()
end_entry=tk.Entry(root, textvariable=end_port).pack(pady=10)

btn=tk.Button(root,text='scan',command=scan).pack()    

root.mainloop()

# %%
from scapy.all import sniff, TCP, IP, Raw, wrpcap

# List to store captured packets
captured_packets = []

# Callback function to process and store packets
def packet_callback(packet):
    if packet.haslayer(IP) and packet.haslayer(TCP):
        ip_layer = packet[IP]
        tcp_layer = packet[TCP]
        print(f"\n{ip_layer.src}:{tcp_layer.sport} -> {ip_layer.dst}:{tcp_layer.dport}")

        # Check for HTTP traffic (port 80)
        if tcp_layer.dport == 80 or tcp_layer.sport == 80:
            if packet.haslayer(Raw):
                payload = packet[Raw].load
                print(f"HTTP Data:\n{payload.decode(errors='ignore')}\n")

        # HTTPS traffic (port 443) - encrypted, only metadata shown
        elif tcp_layer.dport == 443 or tcp_layer.sport == 443:
            print("HTTPS Traffic (Encrypted Data)")

        # Store packet for PCAP save
        captured_packets.append(packet)

# Sniff packets (you can set iface="wlan0" if needed)
print("Sniffing HTTP and HTTPS traffic... Press Ctrl+C to stop.")
try:
    sniff(filter="tcp port 80 or tcp port 443", prn=packet_callback, store=False ,count = 20)
except KeyboardInterrupt:
    print("\nSniffing stopped. Saving to pcap...")

# Save captured packets to a PCAP file
pcap_filename = "http_https_traffic.pcap"
wrpcap(pcap_filename, captured_packets)
print(f"Packets saved to {pcap_filename}")
