# %%
print('hello world')
# Out:
# hello world

# %%
import tkinter as tk
root = tk.Tk()
root.title('My Add')
root.geometry("300x300")
root.mainloop()

# %%
from tkinter import*   #  *=called as wild card
gla_root=Tk()
gla_root.mainloop()

# %%
from tkinter import*
gla_root=Tk()
gla_root.geometry("500x400")  # for screen size modification
gla_root.mainloop()

# %%
from tkinter import*
gla_root=Tk()
gla_root.minsize(120,100)
gla_root.mainloop()

# %%
from tkinter import*
gla_root=Tk()
gla_root.maxsize(100,300)
gla_root.mainloop()

# %%
from tkinter import*
gla_root=Tk()
gla_root=Label(text='GLA University')
gla_root.pack()
gla_root.mainloop()

# %%
from tkinter import*
gla_root=Tk()
gla_root.geometry("700x600")
photo = PhotoImage(file='R.png')
gla=Label(text='GLA University',image=photo )
gla.pack()
gla_root.mainloop()

# %%
#image display using tkinter
from tkinter import*
from PIL import Image,ImageTk 
gla_root=Tk()
gla_root.geometry("700x600")
image= Image.open("b.jpg")
photo= ImageTk.PhotoImage(image)
gla=Label(image=photo)
gla.pack()
gla_root.mainloop()

# %%
#creating button using tkinter
import tkinter as tk

def greet():
    print("welcome")

root = tk.Tk()
button = tk.Button(root, text = "Greet", command = greet)
button.pack()

root.mainloop()
# Out:
# welcome
# welcome

# %%
import tkinter as tk                 #library
from tkinter import messagebox

def greet():                         #function defining
    print("welcome")

#main code
root = tk.Tk()
button = tk.Button(root, text = "Greet", command = greet)
button.pack()

root.mainloop()
# Out:
# welcome

# %%
import tkinter as tk

# Create the main window
root = tk.Tk()
root.geometry("400x250")  # Set window size
root.title("Welcome to My App")  # Set window title

# Create a StringVar to associate with the label
text_var = tk.StringVar()
text_var.set("Hello, World!")

# Create the label widget with all options
label = tk.Label(root, 
                 textvariable=text_var, 
                 anchor=tk.CENTER,       
                 bg="lightblue",      
                 height=3,              
                 width=30,              
                 bd=15,                  
                 font=("Arial", 16, "bold"), 
                 cursor="hand2",   
                 fg="red",             
                 padx=15,               
                 pady=15,                
                 justify=tk.CENTER,    
                 relief=tk.RAISED,     
                 underline=0,           
                 wraplength=250        
                )

# Pack the label into the window
label.pack(pady=20)  # Add some padding to the top


# Run the main event loop
root.mainloop()

# %%
# messagebox using tkinter
import tkinter as tk
from tkinter import messagebox

def greet():
    name = entry_name.get()
    messagebox.showinfo("Greeting", f"Hello, {name}!")

root = tk.Tk()
root.title("Greeting App")

tk.Label(root, text="Enter your name:").pack(pady=5)
entry_name = tk.Entry(root)
entry_name.pack(pady=15)

tk.Button(root, text="Greet Me", command=greet).pack(pady=10)

root.mainloop()

# %%
# Program to make a simple 
# login screen  


import tkinter as tk

 
root=tk.Tk()

# setting the windows size
root.geometry("600x400")
 
# declaring string variable
# for storing name and password
name_var=tk.StringVar()
passw_var=tk.StringVar()

 
# defining a function that will
# get the name and password and 
# print them on the screen
def submit():

    name=name_var.get()
    password=passw_var.get()
    
    print("The name is : " + name)
    print("The password is : " + password)
    
    name_var.set("")
    passw_var.set("")
    
    
# creating a label for 
# name using widget Label
name_label = tk.Label(root, text = 'Username', font=('calibre',10, 'bold'))
 
# creating a entry for input
# name using widget Entry
name_entry = tk.Entry(root,textvariable = name_var, font=('calibre',10,'normal'))
 
# creating a label for password
passw_label = tk.Label(root, text = 'Password', font = ('calibre',10,'bold'))
 
# creating a entry for password
passw_entry=tk.Entry(root, textvariable = passw_var, font = ('calibre',10,'normal'), show = '*')
 
# creating a button using the widget 
# Button that will call the submit function 
sub_btn=tk.Button(root,text = 'Submit', command = submit)
 
# placing the label and entry in
# the required position using grid
# method
name_label.grid(row=0,column=0)
name_entry.grid(row=0,column=1)
passw_label.grid(row=1,column=0)
passw_entry.grid(row=1,column=1)
sub_btn.grid(row=2,column=1)
 
# performing an infinite loop 
# for the window to display
root.mainloop()

# %%
# student registration form


import tkinter as tk
from tkinter import messagebox

root = tk.Tk()
root.title('student registration')
root.geometry('300x500')
root.configure(bg='grey')

name=tk.StringVar()
course=tk.StringVar()
section=tk.StringVar()
FName=tk.StringVar()
Phone_No=tk.StringVar()

def submit():
    name_var=name.get()
    course_var=course.get()
    section_var=section.get()
    FName_var=FName.get()
    Phone_No_var=Phone_No.get()

    print(f'The Name is: {name_var}')
    print(f'The Course is: {course_var}')
    print(f'The Section is: {section_var}')
    print(f'The Father\'s name is: {FName_var}')
    print(f'The PhoneNo is: {Phone_No_var}')

    name.set('')
    course.set('')
    section.set('')
    FName.set('')
    Phone_No.set('')

    messagebox.showinfo(f'Hello {name_var.upper()},', 'You have successfully registered!')

#working without pack() in above code due to grid method         
tk.Label(root,text="Enter your Name:",font=('calibre',10,'bold'),bg='grey').pack()
name_entry=tk.Entry(root, textvariable=name,font=('calibre',10,'normal')).pack(pady=10)

tk.Label(root,text="Enter your Course:",font=('calibre',10,'bold'),bg='grey').pack()
course_entry=tk.Entry(root, textvariable=course,font=('calibre',10,'normal')).pack(pady=10)

tk.Label(root,text="Enter your Section:",font=('calibre',10,'bold'),bg='grey').pack()
section_entry=tk.Entry(root, textvariable=section,font=('calibre',10,'normal')).pack(pady=10)

tk.Label(root,text="Enter your Father's Name:",font=('calibre',10,'bold'),bg='grey').pack()
FName_entry=tk.Entry(root, textvariable=FName,font=('calibre',10,'normal')).pack(pady=10)

tk.Label(root,text="Enter your Phone_No:",font=('calibre',10,'bold'),bg='grey').pack()
Phone_No_entry=tk.Entry(root, textvariable=Phone_No,font=('calibre',10,'normal')).pack(pady=15)

reg_Btn=tk.Button(root,text="Register",command=submit,font=('calibre',10,'bold'),bd=5).pack()

root.mainloop()

# %%
# calculator
from tkinter import*
def click(event):
    global scvalue
    text=event.widget.cget('text')

    if text=="=":
        if scvalue.get().isdigit():
            value=int(scvalue.get())
        else:
            value = eval(screen.get()) 
        scvalue.set(value)
        screen.update()

    elif text=="c":
        scvalue.set("") 
        screen.update()

    else:
        scvalue.set(scvalue.get() +text)
        screen.update()              

root=Tk()
root.title('calculator by ishika')
root.geometry("644x900")

scvalue=StringVar()
scvalue.set("")
screen=Entry(root,textvar=scvalue,font=('lucida',35,'bold'))
screen.pack(fill=X,ipadx=8,pady=10,padx=10) # ipadx = used for font padding

f=Frame(root,bg='grey')

b=Button(f,text='9',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)    # bind = whenever we click on it the text on it will appear
b=Button(f,text='8',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)
b=Button(f,text='7',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)

f.pack()

f=Frame(root,bg='grey')

b=Button(f,text='6',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)   
b=Button(f,text='5',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)
b=Button(f,text='4',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)

f.pack()

f=Frame(root,bg='grey')

b=Button(f,text='3',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)    
b=Button(f,text='2',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)
b=Button(f,text='1',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)

f.pack()

f=Frame(root,bg='grey')

b=Button(f,text='+',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)   
b=Button(f,text='-',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)
b=Button(f,text='*',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)

f.pack()

f=Frame(root,bg='grey')

b=Button(f,text='c',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)    
b=Button(f,text='=',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)  
b=Button(f,text='/',padx=28,pady=22,font=('lucida',35,'bold'))
b.pack(side=LEFT)
b.bind("<Button-1>",click)  


f.pack()

root.mainloop()

# %%
# interface to write
from tkinter import*

root=Tk()
root.title('calculator by ishika')
root.geometry("344x500")

scvalue=StringVar()
scvalue.set("")
screen=Entry(root,textvar=scvalue,font=('lucida',10,'bold')).pack()

root.mainloop()

# %%
#interface
import tkinter as tk

root=Tk()
root.title('')
root.geometry("400x400")

scvalue=tk.StringVar()
scvalue.set("")
screen=Entry(root,textvar=scvalue).pack()

root.mainloop()
